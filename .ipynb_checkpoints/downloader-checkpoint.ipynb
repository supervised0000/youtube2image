# %%
# !pip install pytube
# Out:
# Requirement already satisfied: pytube in c:\users\h2hb0\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (12.1.0)

# %%
from pytube import YouTube
import os
import glob
import cv2


file_dir = os.getcwd()
txt_list = glob.glob(os.path.join(file_dir, '*.txt'))

# %%
for txt in txt_list:
    file_name = os.path.basename(txt)
    cls = file_name.split(".")[0]
    
    save_dir = os.path.join(file_dir,"src")
    
    if os.path.exists(save_dir) == False:
        os.mkdir(save_dir)

    print(f"Downloading videos is started")
    
    with open(txt, "r") as f:
        urllines = f.readlines()

        for idx ,url in enumerate(urllines):
            yt = YouTube(url)
            try:
                print(f"Video {yt.title} is downloading...")
                stream = yt.streams.get_highest_resolution()
                stream.download(save_dir)
                print(f"> Downloading {yt.title} is finished\n")
            except:
                print(">>> Something is wrong, stop downloading current file...\n")
            
        print(f"< Downloading videos is finished >\n")

print("Done!")
# Out:
# Downloading videos is started
# Video Shipyard Skyscrapers - London 4K - Driving Downtown is downloading...
# Downloading Shipyard Skyscrapers - London 4K - Driving Downtown is finished
# Video TOKYO NIGHT DRIVE | 深夜の六本木通りを夜景ドライブ [4K] Roppongi-dori Avenue at Midnight, Tokyo, Japan is downloading...
# Downloading TOKYO NIGHT DRIVE | 深夜の六本木通りを夜景ドライブ [4K] Roppongi-dori Avenue at Midnight, Tokyo, Japan is finished
# Video Driving Downtown - Vienna 4K - Austria is downloading...
# Downloading Driving Downtown - Vienna 4K - Austria is finished
# Video Expressway Loop - Paris 4K - Sunday Morning Drive is downloading...
# Downloading Expressway Loop - Paris 4K - Sunday Morning Drive is finished
# Video [4K] Night Driving in Seoul is downloading...
# Downloading [4K] Night Driving in Seoul is finished
# Video [4K] Drive in Downtown Seoul On The Day The Typhoon Passed POV 태풍 마이삭이 지나간 오후의 서울 도심 드라이브 is downloading...
# Downloading [4K] Drive in Downtown Seoul On The Day The Typhoon Passed POV 태풍 마이삭이 지나간 오후의 서울 도심 드라이브 is finished
# Video [4K] Driving Downtown Seoul Gangnam, Teheran, Cheongdam POV is downloading...
# Downloading [4K] Driving Downtown Seoul Gangnam, Teheran, Cheongdam POV is finished
# Video Dublin 4K60FPS HDR - Rainy Day - Driving Downtown - Ireland is downloading...
# Downloading Dublin 4K60FPS HDR - Rainy Day - Driving Downtown - Ireland is finished
# Video Los Angeles 4K - California Glow - Scenic Drive is downloading...
# Downloading Los Angeles 4K - California Glow - Scenic Drive is finished
# Video Seoul Night Drive 🌠 | Downtown Vibes | Chill Lofi Hiphop Beats | POV 4K HDR is downloading...
# Downloading Seoul Night Drive 🌠 | Downtown Vibes | Chill Lofi Hiphop Beats | POV 4K HDR is finished
# Video 🧨9:00pm : for tonight is downloading...
# Downloading 🧨9:00pm : for tonight is finished
# Video 4K Night Drive under Dubai Skyscrapers 55km (Sunset Drive#5 faster & longer ver.) is downloading...
# Downloading 4K Night Drive under Dubai Skyscrapers 55km (Sunset Drive#5 faster & longer ver.) is finished
# Video Night Driving 4K - Center of Tokyo - Imperial Palace, Tokyo Station, Ginza, Nihonbashi in Japan is downloading...
# Downloading Night Driving 4K - Center of Tokyo - Imperial Palace, Tokyo Station, Ginza, Nihonbashi in Japan is finished
# Video Driving in Moscow at Night 4K with Music is downloading...
# Downloading Driving in Moscow at Night 4K with Music is finished
# Video Detroit 4K - Neon Nightlife - Driving Downtown is downloading...
# Downloading Detroit 4K - Neon Nightlife - Driving Downtown is finished
# Video Korea Seoul 4K - Driving Downtown - Night Drive is downloading...
# Downloading Korea Seoul 4K - Driving Downtown - Night Drive is finished
# Video Driving in Seoul 4 : Driving Downtown | Night Drive 4K is downloading...
# Downloading Driving in Seoul 4 : Driving Downtown | Night Drive 4K is finished
# Video Highway drive from sunset to night, 고속도로 야간 주행 | 4K is downloading...
# Downloading Highway drive from sunset to night, 고속도로 야간 주행 | 4K is finished
# Video [4k] Olympic Road - Night Driving in Seoul Olympic Way 💇🏻 올림픽대로 | 반포 - 노량진 | バームドライブ | 夜间兜风 is downloading...
# Downloading [4k] Olympic Road - Night Driving in Seoul Olympic Way 💇🏻 올림픽대로 | 반포 - 노량진 | バームドライブ | 夜间兜风 is finished
# Video EDSA Night Drive | Full Driving Tour | Pasay to Monumento | 4K | Philippines is downloading...
# Downloading EDSA Night Drive | Full Driving Tour | Pasay to Monumento | 4K | Philippines is finished
# Video Night Drive - Delhi 4K - India is downloading...
# Downloading Night Drive - Delhi 4K - India is finished
# Video [4K] Gangnam Drive - Night driving Seoul, South Korea | 한국 서울 야간 운전 드라이브 ソウル韓国ナイトドライブツアー is downloading...
# Downloading [4K] Gangnam Drive - Night driving Seoul, South Korea | 한국 서울 야간 운전 드라이브 ソウル韓国ナイトドライブツアー is finished
# Downloading videos is finished
# Done!

# %%
def extract_frame(file_dir ,file_name):
    
    filepath = os.path.join(file_dir,"src", file_name)
    video = cv2.VideoCapture(filepath) #'' 사이에 사용할 비디오 파일의 경로 및 이름을 넣어주도록 함
    
    if not video.isOpened():
        print("Could not Open :", filepath)
        exit(0)


    length = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = video.get(cv2.CAP_PROP_FPS)

    print("length :", length)
    print("width :", width)
    print("height :", height)
    print("fps :", fps)
    
    frame_dir = os.path.join(file_dir,"frame")
    frame_path = os.path.join(frame_dir, file_name[:-4])
    
    try:
        if not os.path.exists(frame_path):
            os.makedirs(frame_path)
            
    except OSError:
        print ('Error: Creating directory. ' +  frame_path)

    count = 0

    while (video.isOpened()):
        ret, image = video.read()
        if (int(video.get(1)) % 10 == 0):  # 앞서 불러온 fps 값을 사용하여 1초마다 추출
            #print("START")

            cv2.imwrite(frame_path + "/frame%d.jpg" % count, image)
            print('Saved frame number :', str(int(video.get(1))))
            count += 1

    video.release()

# %%
filepath = os.path.join(file_dir, "src")
file_list = []

for file in os.listdir(filepath):
    if file.endswith(".mp4"):
        file_list.append(file)

for file in file_list:
    extract_frame(file_dir, file)
# Out:
# length : 22619
# width : 1280
# height : 720
# fps : 29.97
# Saved frame number : 10
# Saved frame number : 20
# Saved frame number : 30
# Saved frame number : 40
# Saved frame number : 50
# Saved frame number : 60
# Saved frame number : 70
# Saved frame number : 80
# Saved frame number : 90
# Saved frame number : 100
# Saved frame number : 110
# Saved frame number : 120
# Saved frame number : 130
# Saved frame number : 140
# Saved frame number : 150
# Saved frame number : 160
# Saved frame number : 170
# Saved frame number : 180
# Saved frame number : 190
# Saved frame number : 200
# Saved frame number : 210
# Saved frame number : 220
# Saved frame number : 230
# Saved frame number : 240
# Saved frame number : 250
# Saved frame number : 260
# Saved frame number : 270
# Saved frame number : 280
# Saved frame number : 290
# Saved frame number : 300
# Saved frame number : 310
# Saved frame number : 320
# Saved frame number : 330
# Saved frame number : 340
# Saved frame number : 350
# Saved frame number : 360
# Saved frame number : 370
# Saved frame number : 380
# Saved frame number : 390
# Saved frame number : 400
# Saved frame number : 410
# Saved frame number : 420
# Saved frame number : 430
# Saved frame number : 440
# Saved frame number : 450
# Saved frame number : 460
# Saved frame number : 470
# Saved frame number : 480
# Saved frame number : 490
# Saved frame number : 500
# Saved frame number : 510
# Saved frame number : 520
# Saved frame number : 530
# Saved frame number : 540
# Saved frame number : 550
# Saved frame number : 560
# Saved frame number : 570
# Saved frame number : 580
# Saved frame number : 590
# Saved frame number : 600
# Saved frame number : 610
# Saved frame number : 620
# Saved frame number : 630
# Saved frame number : 640
# Saved frame number : 650
# Saved frame number : 660
# Saved frame number : 670
# Saved frame number : 680
# Saved frame number : 690
# Saved frame number : 700
# Saved frame number : 710
# Saved frame number : 720
# Saved frame number : 730
# Saved frame number : 740
# Saved frame number : 750
# Saved frame number : 760
# Saved frame number : 770
# Saved frame number : 780
# Saved frame number : 790
# Saved frame number : 800
# Saved frame number : 810
# Saved frame number : 820
# Saved frame number : 830
# Saved frame number : 840
# Saved frame number : 850
# Saved frame number : 860
# Saved frame number : 870
# Saved frame number : 880
# Saved frame number : 890
# Saved frame number : 900
# Saved frame number : 910
# Saved frame number : 920
# Saved frame number : 930
# Saved frame number : 940
# Saved frame number : 950
# Saved frame number : 960
# Saved frame number : 970
# Saved frame number : 980
# Saved frame number : 990
# Saved frame number : 1000
# Saved frame number : 1010
# Saved frame number : 1020
# Saved frame number : 1030
# Saved frame number : 1040
# Saved frame number : 1050
# Saved frame number : 1060
# Saved frame number : 1070
# Saved frame number : 1080
# Saved frame number : 1090
# Saved frame number : 1100
# Saved frame number : 1110
# Saved frame number : 1120
# Saved frame number : 1130
# Saved frame number : 1140
# Saved frame number : 1150
# Saved frame number : 1160
# Saved frame number : 1170
# Saved frame number : 1180
# Saved frame number : 1190
# Saved frame number : 1200
# Saved frame number : 1210
# Saved frame number : 1220
# Saved frame number : 1230
# Saved frame number : 1240
# Saved frame number : 1250
# Saved frame number : 1260
# Saved frame number : 1270
# Saved frame number : 1280
# Saved frame number : 1290
# Saved frame number : 1300
# Saved frame number : 1310
# Saved frame number : 1320
# Saved frame number : 1330
# Saved frame number : 1340
# Saved frame number : 1350
# Saved frame number : 1360
# Saved frame number : 1370
# Saved frame number : 1380
# Saved frame number : 1390
# Saved frame number : 1400
# Saved frame number : 1410
# Saved frame number : 1420
# Saved frame number : 1430
# Saved frame number : 1440
# Saved frame number : 1450
# Saved frame number : 1460
# Saved frame number : 1470
# Saved frame number : 1480
# Saved frame number : 1490
# Saved frame number : 1500
# Saved frame number : 1510
# Saved frame number : 1520
# Saved frame number : 1530
# Saved frame number : 1540
# Saved frame number : 1550
# Saved frame number : 1560
# Saved frame number : 1570
# Saved frame number : 1580
# Saved frame number : 1590
# Saved frame number : 1600
# Saved frame number : 1610
# Saved frame number : 1620
# Saved frame number : 1630
# Saved frame number : 1640
# Saved frame number : 1650
# Saved frame number : 1660
# Saved frame number : 1670
# Saved frame number : 1680
# Saved frame number : 1690
# Saved frame number : 1700
# Saved frame number : 1710
# Saved frame number : 1720
# Saved frame number : 1730
# Saved frame number : 1740
# Saved frame number : 1750
# Saved frame number : 1760
# Saved frame number : 1770
# Saved frame number : 1780
# Saved frame number : 1790
# Saved frame number : 1800
# Saved frame number : 1810
# Saved frame number : 1820
# Saved frame number : 1830
# Saved frame number : 1840
# Saved frame number : 1850
# Saved frame number : 1860
# Saved frame number : 1870
# Saved frame number : 1880
# Saved frame number : 1890
# Saved frame number : 1900
# Saved frame number : 1910
# Saved frame number : 1920
# Saved frame number : 1930
# Saved frame number : 1940
# Saved frame number : 1950
# Saved frame number : 1960
# Saved frame number : 1970
# Saved frame number : 1980
# Saved frame number : 1990
# Saved frame number : 2000
# Saved frame number : 2010
# Saved frame number : 2020
# Saved frame number : 2030
# Saved frame number : 2040
# Saved frame number : 2050
# Saved frame number : 2060
# Saved frame number : 2070
# Saved frame number : 2080
# Saved frame number : 2090
# Saved frame number : 2100
# Saved frame number : 2110
# Saved frame number : 2120
# Saved frame number : 2130
# Saved frame number : 2140
# Saved frame number : 2150
# Saved frame number : 2160
# Saved frame number : 2170
# Saved frame number : 2180
# Saved frame number : 2190
# Saved frame number : 2200
# Saved frame number : 2210
# Saved frame number : 2220
# Saved frame number : 2230
# Saved frame number : 2240
# Saved frame number : 2250
# Saved frame number : 2260
# Saved frame number : 2270
# Saved frame number : 2280
# Saved frame number : 2290
# Saved frame number : 2300
# Saved frame number : 2310
# Saved frame number : 2320
# Saved frame number : 2330
# Saved frame number : 2340
# Saved frame number : 2350
# Saved frame number : 2360
# Saved frame number : 2370
# Saved frame number : 2380
# Saved frame number : 2390
# Saved frame number : 2400
# Saved frame number : 2410
# Saved frame number : 2420
# Saved frame number : 2430
# Saved frame number : 2440
# Saved frame number : 2450
# Saved frame number : 2460
# Saved frame number : 2470
# Saved frame number : 2480
# Saved frame number : 2490
# Saved frame number : 2500
# Saved frame number : 2510
# Saved frame number : 2520
# Saved frame number : 2530
# Saved frame number : 2540
# Saved frame number : 2550
# Saved frame number : 2560
# Saved frame number : 2570
# Saved frame number : 2580
# Saved frame number : 2590
# Saved frame number : 2600
# Saved frame number : 2610
# Saved frame number : 2620
# Saved frame number : 2630
# Saved frame number : 2640
# Saved frame number : 2650
# Saved frame number : 2660
# Saved frame number : 2670
# Saved frame number : 2680
# Saved frame number : 2690
# Saved frame number : 2700
# Saved frame number : 2710
# Saved frame number : 2720
# Saved frame number : 2730
# Saved frame number : 2740
# Saved frame number : 2750
# Saved frame number : 2760
# Saved frame number : 2770
# Saved frame number : 2780
# Saved frame number : 2790
# Saved frame number : 2800
# Saved frame number : 2810
# Saved frame number : 2820
# Saved frame number : 2830
# Saved frame number : 2840
# Saved frame number : 2850
# Saved frame number : 2860
# Saved frame number : 2870
# Saved frame number : 2880
# Saved frame number : 2890
# Saved frame number : 2900
# Saved frame number : 2910
# Saved frame number : 2920
# Saved frame number : 2930
# Saved frame number : 2940
# Saved frame number : 2950
# Saved frame number : 2960
# Saved frame number : 2970
# Saved frame number : 2980
# Saved frame number : 2990
# Saved frame number : 3000
# Saved frame number : 3010
# Saved frame number : 3020
# Saved frame number : 3030
# Saved frame number : 3040
# Saved frame number : 3050
# Saved frame number : 3060
# Saved frame number : 3070
# Saved frame number : 3080
# Saved frame number : 3090
# Saved frame number : 3100
# Saved frame number : 3110
# Saved frame number : 3120
# Saved frame number : 3130
# Saved frame number : 3140
# Saved frame number : 3150
# Saved frame number : 3160
# Saved frame number : 3170
# Saved frame number : 3180
# Saved frame number : 3190
# Saved frame number : 3200
# Saved frame number : 3210
# Saved frame number : 3220
# Saved frame number : 3230
# Saved frame number : 3240
# Saved frame number : 3250
# Saved frame number : 3260
# Saved frame number : 3270
# Saved frame number : 3280
# Saved frame number : 3290
# Saved frame number : 3300
# Saved frame number : 3310
# Saved frame number : 3320
# Saved frame number : 3330
# Saved frame number : 3340
# Saved frame number : 3350
# Saved frame number : 3360
# Saved frame number : 3370
# Saved frame number : 3380
# Saved frame number : 3390
# Saved frame number : 3400
# Saved frame number : 3410
# Saved frame number : 3420
# Saved frame number : 3430
# Saved frame number : 3440
# Saved frame number : 3450
# Saved frame number : 3460
# Saved frame number : 3470
# Saved frame number : 3480
# Saved frame number : 3490
# Saved frame number : 3500
# Saved frame number : 3510
# Saved frame number : 3520
# Saved frame number : 3530
# Saved frame number : 3540
# Saved frame number : 3550
# Saved frame number : 3560
# Saved frame number : 3570
# Saved frame number : 3580
# Saved frame number : 3590
# Saved frame number : 3600
# Saved frame number : 3610
# Saved frame number : 3620
# Saved frame number : 3630
# Saved frame number : 3640
# Saved frame number : 3650
# Saved frame number : 3660
# Saved frame number : 3670
# Saved frame number : 3680
# Saved frame number : 3690
# Saved frame number : 3700
# Saved frame number : 3710
# Saved frame number : 3720
# Saved frame number : 3730
# Saved frame number : 3740
# Saved frame number : 3750
# Saved frame number : 3760
# Saved frame number : 3770
# Saved frame number : 3780
# Saved frame number : 3790
# Saved frame number : 3800
# Saved frame number : 3810
# Saved frame number : 3820
# Saved frame number : 3830
# Saved frame number : 3840
# Saved frame number : 3850
# Saved frame number : 3860
# Saved frame number : 3870
# Saved frame number : 3880
# Saved frame number : 3890
# Saved frame number : 3900
# Saved frame number : 3910
# Saved frame number : 3920
# Saved frame number : 3930
# Saved frame number : 3940
# Saved frame number : 3950
# Saved frame number : 3960
# Saved frame number : 3970
# Saved frame number : 3980
# Saved frame number : 3990
# Saved frame number : 4000
# Saved frame number : 4010
# Saved frame number : 4020
# Saved frame number : 4030
# Saved frame number : 4040
# Saved frame number : 4050
# Saved frame number : 4060
# Saved frame number : 4070
# Saved frame number : 4080
# Saved frame number : 4090
# Saved frame number : 4100
# Saved frame number : 4110
# Saved frame number : 4120
# Saved frame number : 4130
# Saved frame number : 4140
# Saved frame number : 4150
# Saved frame number : 4160
# Saved frame number : 4170
# Saved frame number : 4180
# Saved frame number : 4190
# Saved frame number : 4200
# Saved frame number : 4210
# Saved frame number : 4220
# Saved frame number : 4230
# Saved frame number : 4240
# Saved frame number : 4250
# Saved frame number : 4260
# Saved frame number : 4270
# Saved frame number : 4280
# Saved frame number : 4290
# Saved frame number : 4300
# Saved frame number : 4310
# Saved frame number : 4320
# Saved frame number : 4330
# Saved frame number : 4340
# Saved frame number : 4350
# Saved frame number : 4360
# Saved frame number : 4370
# Saved frame number : 4380
# Saved frame number : 4390
# Saved frame number : 4400
# Saved frame number : 4410
# Saved frame number : 4420
# Saved frame number : 4430
# Saved frame number : 4440
# Saved frame number : 4450
# Saved frame number : 4460
# Saved frame number : 4470
# Saved frame number : 4480
# Saved frame number : 4490
# Saved frame number : 4500
# Saved frame number : 4510
# Saved frame number : 4520
# Saved frame number : 4530
# Saved frame number : 4540
# Saved frame number : 4550
# Saved frame number : 4560
# Saved frame number : 4570
# Saved frame number : 4580
# Saved frame number : 4590
# Saved frame number : 4600
# Saved frame number : 4610
# Saved frame number : 4620
# Saved frame number : 4630
# Saved frame number : 4640
# Saved frame number : 4650
# Saved frame number : 4660
# Saved frame number : 4670
# Saved frame number : 4680
# Saved frame number : 4690
# Saved frame number : 4700
# Saved frame number : 4710
# Saved frame number : 4720
# Saved frame number : 4730
# Saved frame number : 4740
# Saved frame number : 4750
# Saved frame number : 4760
# Saved frame number : 4770
# Saved frame number : 4780
# Saved frame number : 4790
# Saved frame number : 4800
# Saved frame number : 4810
# Saved frame number : 4820
# Saved frame number : 4830
# Saved frame number : 4840
# Saved frame number : 4850
# Saved frame number : 4860
# Saved frame number : 4870
# Saved frame number : 4880
# Saved frame number : 4890
# Saved frame number : 4900
# Saved frame number : 4910
# Saved frame number : 4920
# Saved frame number : 4930
# Saved frame number : 4940
# Saved frame number : 4950
# Saved frame number : 4960
# Saved frame number : 4970
# Saved frame number : 4980
# Saved frame number : 4990
# Saved frame number : 5000
# Saved frame number : 5010
# Saved frame number : 5020
# Saved frame number : 5030
# Saved frame number : 5040
# Saved frame number : 5050
# Saved frame number : 5060
# Saved frame number : 5070
# Saved frame number : 5080
# Saved frame number : 5090
# Saved frame number : 5100
# Saved frame number : 5110
# Saved frame number : 5120
# Saved frame number : 5130
# Saved frame number : 5140
# Saved frame number : 5150
# Saved frame number : 5160
# Saved frame number : 5170
# Saved frame number : 5180
# Saved frame number : 5190
# Saved frame number : 5200
# Saved frame number : 5210
# Saved frame number : 5220
# Saved frame number : 5230
# Saved frame number : 5240
# Saved frame number : 5250
# Saved frame number : 5260
# Saved frame number : 5270
# Saved frame number : 5280
# Saved frame number : 5290
# Saved frame number : 5300
# Saved frame number : 5310
# Saved frame number : 5320
# Saved frame number : 5330
# Saved frame number : 5340
# Saved frame number : 5350
# Saved frame number : 5360
# Saved frame number : 5370
# Saved frame number : 5380
# Saved frame number : 5390
# Saved frame number : 5400
# Saved frame number : 5410
# Saved frame number : 5420
# Saved frame number : 5430
# Saved frame number : 5440
# Saved frame number : 5450
# Saved frame number : 5460
# Saved frame number : 5470
# Saved frame number : 5480
# Saved frame number : 5490
# Saved frame number : 5500
# Saved frame number : 5510
# Saved frame number : 5520
# Saved frame number : 5530
# Saved frame number : 5540
# Saved frame number : 5550
# Saved frame number : 5560
# Saved frame number : 5570
# Saved frame number : 5580
# Saved frame number : 5590
# Saved frame number : 5600
# Saved frame number : 5610
# Saved frame number : 5620
# Saved frame number : 5630
# Saved frame number : 5640
# Saved frame number : 5650
# Saved frame number : 5660
# Saved frame number : 5670
# Saved frame number : 5680
# Saved frame number : 5690
# Saved frame number : 5700
# Saved frame number : 5710
# Saved frame number : 5720
# Saved frame number : 5730
# Saved frame number : 5740
# Saved frame number : 5750
# Saved frame number : 5760
# Saved frame number : 5770
# Saved frame number : 5780
# Saved frame number : 5790
# Saved frame number : 5800
# Saved frame number : 5810
# Saved frame number : 5820
# Saved frame number : 5830
# Saved frame number : 5840
# Saved frame number : 5850
# Saved frame number : 5860
# Saved frame number : 5870
# Saved frame number : 5880
# Saved frame number : 5890
# Saved frame number : 5900
# Saved frame number : 5910
# Saved frame number : 5920
# Saved frame number : 5930
# Saved frame number : 5940
# Saved frame number : 5950
# Saved frame number : 5960
# Saved frame number : 5970
# Saved frame number : 5980
# Saved frame number : 5990
# Saved frame number : 6000
# Saved frame number : 6010
# Saved frame number : 6020
# Saved frame number : 6030
# Saved frame number : 6040
# Saved frame number : 6050
# Saved frame number : 6060
# Saved frame number : 6070
# Saved frame number : 6080
# Saved frame number : 6090
# Saved frame number : 6100
# Saved frame number : 6110
# Saved frame number : 6120
# Saved frame number : 6130
# Saved frame number : 6140
# Saved frame number : 6150
# Saved frame number : 6160
# Saved frame number : 6170
# Saved frame number : 6180
# Saved frame number : 6190
# Saved frame number : 6200
# Saved frame number : 6210
# Saved frame number : 6220
# Saved frame number : 6230
# Saved frame number : 6240
# Saved frame number : 6250
# Saved frame number : 6260
# Saved frame number : 6270
# Saved frame number : 6280
# Saved frame number : 6290
# Saved frame number : 6300
# Saved frame number : 6310
# Saved frame number : 6320
# Saved frame number : 6330
# Saved frame number : 6340
# Saved frame number : 6350
# Saved frame number : 6360
# Saved frame number : 6370
# Saved frame number : 6380
# Saved frame number : 6390
# Saved frame number : 6400
# Saved frame number : 6410
# Saved frame number : 6420
# Saved frame number : 6430
# Saved frame number : 6440
# Saved frame number : 6450
# Saved frame number : 6460
# Saved frame number : 6470
# Saved frame number : 6480
# Saved frame number : 6490
# Saved frame number : 6500
# Saved frame number : 6510
# Saved frame number : 6520
# Saved frame number : 6530
# Saved frame number : 6540
# Saved frame number : 6550
# Saved frame number : 6560
# Saved frame number : 6570
# Saved frame number : 6580
# Saved frame number : 6590
# Saved frame number : 6600
# Saved frame number : 6610
# Saved frame number : 6620
# Saved frame number : 6630
# Saved frame number : 6640
# Saved frame number : 6650
# Saved frame number : 6660
# Saved frame number : 6670
# Saved frame number : 6680
# Saved frame number : 6690
# Saved frame number : 6700
# Saved frame number : 6710
# Saved frame number : 6720
# Saved frame number : 6730
# Saved frame number : 6740
# Saved frame number : 6750
# Saved frame number : 6760
# Saved frame number : 6770
# Saved frame number : 6780
# Saved frame number : 6790
# Saved frame number : 6800
# Saved frame number : 6810
# Saved frame number : 6820
# Saved frame number : 6830
# Saved frame number : 6840
# Saved frame number : 6850
# Saved frame number : 6860
# Saved frame number : 6870
# Saved frame number : 6880
# Saved frame number : 6890
# Saved frame number : 6900
# Saved frame number : 6910
# Saved frame number : 6920
# Saved frame number : 6930
# Saved frame number : 6940
# Saved frame number : 6950
# Saved frame number : 6960
# Saved frame number : 6970
# Saved frame number : 6980
# Saved frame number : 6990
# Saved frame number : 7000
# Saved frame number : 7010
# Saved frame number : 7020
# Saved frame number : 7030
# Saved frame number : 7040
# Saved frame number : 7050
# Saved frame number : 7060
# Saved frame number : 7070
# Saved frame number : 7080
# Saved frame number : 7090
# Saved frame number : 7100
# Saved frame number : 7110
# Saved frame number : 7120
# Saved frame number : 7130
# Saved frame number : 7140
# Saved frame number : 7150
# Saved frame number : 7160
# Saved frame number : 7170
# Saved frame number : 7180
# Saved frame number : 7190
# Saved frame number : 7200
# Saved frame number : 7210
# Saved frame number : 7220
# Saved frame number : 7230
# Saved frame number : 7240
# Saved frame number : 7250
# Saved frame number : 7260
# Saved frame number : 7270
# Saved frame number : 7280
# Saved frame number : 7290
# Saved frame number : 7300
# Saved frame number : 7310
# Saved frame number : 7320
# Saved frame number : 7330
# Saved frame number : 7340
# Saved frame number : 7350
# Saved frame number : 7360
# Saved frame number : 7370
# Saved frame number : 7380
# Saved frame number : 7390
# Saved frame number : 7400
# Saved frame number : 7410
# Saved frame number : 7420
# Saved frame number : 7430
# Saved frame number : 7440
# Saved frame number : 7450
# Saved frame number : 7460
# Saved frame number : 7470
# Saved frame number : 7480
# Saved frame number : 7490
# Saved frame number : 7500
# Saved frame number : 7510
# Saved frame number : 7520
# Saved frame number : 7530
# Saved frame number : 7540
# Saved frame number : 7550
# Saved frame number : 7560
# Saved frame number : 7570
# Saved frame number : 7580
# Saved frame number : 7590
# Saved frame number : 7600
# Saved frame number : 7610
# Saved frame number : 7620
# Saved frame number : 7630
# Saved frame number : 7640
# Saved frame number : 7650
# Saved frame number : 7660
# Saved frame number : 7670
# Saved frame number : 7680
# Saved frame number : 7690
# Saved frame number : 7700
# Saved frame number : 7710
# Saved frame number : 7720
# Saved frame number : 7730
# Saved frame number : 7740
# Saved frame number : 7750
# Saved frame number : 7760
# Saved frame number : 7770
# Saved frame number : 7780
# Saved frame number : 7790
# Saved frame number : 7800
# Saved frame number : 7810
# Saved frame number : 7820
# Saved frame number : 7830
# Saved frame number : 7840
# Saved frame number : 7850
# Saved frame number : 7860
# Saved frame number : 7870
# Saved frame number : 7880
# Saved frame number : 7890
# Saved frame number : 7900
# Saved frame number : 7910
# Saved frame number : 7920
# Saved frame number : 7930
# Saved frame number : 7940
# Saved frame number : 7950
# Saved frame number : 7960
# Saved frame number : 7970
# Saved frame number : 7980
# Saved frame number : 7990
# Saved frame number : 8000
# Saved frame number : 8010
# Saved frame number : 8020
# Saved frame number : 8030
# Saved frame number : 8040
# Saved frame number : 8050
# Saved frame number : 8060
# Saved frame number : 8070
# Saved frame number : 8080
# Saved frame number : 8090
# Saved frame number : 8100
# Saved frame number : 8110
# Saved frame number : 8120
# Saved frame number : 8130
# Saved frame number : 8140
# Saved frame number : 8150
# Saved frame number : 8160
# Saved frame number : 8170
# Saved frame number : 8180
# Saved frame number : 8190
# Saved frame number : 8200
# Saved frame number : 8210
# Saved frame number : 8220
# Saved frame number : 8230
# Saved frame number : 8240
# Saved frame number : 8250
# Saved frame number : 8260
# Saved frame number : 8270
# Saved frame number : 8280
# Saved frame number : 8290
# Saved frame number : 8300
# Saved frame number : 8310
# Saved frame number : 8320
# Saved frame number : 8330
# Saved frame number : 8340
# Saved frame number : 8350
# Saved frame number : 8360
# Saved frame number : 8370
# Saved frame number : 8380
# Saved frame number : 8390
# Saved frame number : 8400
# Saved frame number : 8410
# Saved frame number : 8420
# Saved frame number : 8430
# Saved frame number : 8440
# Saved frame number : 8450
# Saved frame number : 8460
# Saved frame number : 8470
# Saved frame number : 8480
# Saved frame number : 8490
# Saved frame number : 8500
# Saved frame number : 8510
# Saved frame number : 8520
# Saved frame number : 8530
# Saved frame number : 8540
# Saved frame number : 8550
# Saved frame number : 8560
# Saved frame number : 8570
# Saved frame number : 8580
# Saved frame number : 8590
# Saved frame number : 8600
# Saved frame number : 8610
# Saved frame number : 8620
# Saved frame number : 8630
# Saved frame number : 8640
# Saved frame number : 8650
# Saved frame number : 8660
# Saved frame number : 8670
# Saved frame number : 8680
# Saved frame number : 8690
# Saved frame number : 8700
# Saved frame number : 8710
# Saved frame number : 8720
# Saved frame number : 8730
# Saved frame number : 8740
# Saved frame number : 8750
# Saved frame number : 8760
# Saved frame number : 8770
# Saved frame number : 8780
# Saved frame number : 8790
# Saved frame number : 8800
# Saved frame number : 8810
# Saved frame number : 8820
# Saved frame number : 8830
# Saved frame number : 8840
# Saved frame number : 8850
# Saved frame number : 8860
# Saved frame number : 8870
# Saved frame number : 8880
# Saved frame number : 8890
# Saved frame number : 8900
# Saved frame number : 8910
# Saved frame number : 8920
# Saved frame number : 8930
# Saved frame number : 8940
# Saved frame number : 8950
# Saved frame number : 8960
# Saved frame number : 8970
# Saved frame number : 8980
# Saved frame number : 8990
# Saved frame number : 9000
# Saved frame number : 9010
# Saved frame number : 9020
# Saved frame number : 9030
# Saved frame number : 9040
# Saved frame number : 9050
# Saved frame number : 9060
# Saved frame number : 9070
# Saved frame number : 9080
# Saved frame number : 9090
# Saved frame number : 9100
# Saved frame number : 9110
# Saved frame number : 9120
# Saved frame number : 9130
# Saved frame number : 9140
# Saved frame number : 9150
# Saved frame number : 9160
# Saved frame number : 9170
# Saved frame number : 9180
# Saved frame number : 9190
# Saved frame number : 9200
# Saved frame number : 9210
# Saved frame number : 9220
# Saved frame number : 9230
# Saved frame number : 9240
# Saved frame number : 9250
# Saved frame number : 9260
# Saved frame number : 9270
# Saved frame number : 9280
# Saved frame number : 9290
# Saved frame number : 9300
# Saved frame number : 9310
# Saved frame number : 9320
# Saved frame number : 9330
# Saved frame number : 9340
# Saved frame number : 9350
# Saved frame number : 9360
# Saved frame number : 9370
# Saved frame number : 9380
# Saved frame number : 9390
# Saved frame number : 9400
# Saved frame number : 9410
# Saved frame number : 9420
# Saved frame number : 9430
# Saved frame number : 9440
# Saved frame number : 9450
# Saved frame number : 9460
# Saved frame number : 9470
# Saved frame number : 9480
# Saved frame number : 9490
# Saved frame number : 9500
# Saved frame number : 9510
# Saved frame number : 9520
# Saved frame number : 9530
# Saved frame number : 9540
# Saved frame number : 9550
# Saved frame number : 9560
# Saved frame number : 9570
# Saved frame number : 9580
# Saved frame number : 9590
# Saved frame number : 9600
# Saved frame number : 9610
# Saved frame number : 9620
# Saved frame number : 9630
# Saved frame number : 9640
# Saved frame number : 9650
# Saved frame number : 9660
# Saved frame number : 9670
# Saved frame number : 9680
# Saved frame number : 9690
# Saved frame number : 9700
# Saved frame number : 9710
# Saved frame number : 9720
# Saved frame number : 9730
# Saved frame number : 9740
# Saved frame number : 9750
# Saved frame number : 9760
# Saved frame number : 9770
# Saved frame number : 9780
# Saved frame number : 9790
# Saved frame number : 9800
# Saved frame number : 9810
# Saved frame number : 9820
# Saved frame number : 9830
# Saved frame number : 9840
# Saved frame number : 9850
# Saved frame number : 9860
# Saved frame number : 9870
# Saved frame number : 9880
# Saved frame number : 9890
# Saved frame number : 9900
# Saved frame number : 9910
# Saved frame number : 9920
# Saved frame number : 9930
# Saved frame number : 9940
# Saved frame number : 9950
# Saved frame number : 9960
# Saved frame number : 9970
# Saved frame number : 9980
# Saved frame number : 9990
# Saved frame number : 10000
# Saved frame number : 10010
# Saved frame number : 10020
# Saved frame number : 10030
# Saved frame number : 10040
# Saved frame number : 10050
# Saved frame number : 10060
# Saved frame number : 10070
# Saved frame number : 10080
# Saved frame number : 10090
# Saved frame number : 10100
# Saved frame number : 10110
# Saved frame number : 10120
# Saved frame number : 10130
# Saved frame number : 10140
# Saved frame number : 10150
# Saved frame number : 10160
# Saved frame number : 10170
# Saved frame number : 10180
# Saved frame number : 10190
# Saved frame number : 10200
# Saved frame number : 10210
# Saved frame number : 10220
# Saved frame number : 10230
# Saved frame number : 10240
# Saved frame number : 10250
# Saved frame number : 10260
# Saved frame number : 10270
# Saved frame number : 10280
# Saved frame number : 10290
# Saved frame number : 10300
# Saved frame number : 10310
# Saved frame number : 10320
# Saved frame number : 10330
# Saved frame number : 10340
# Saved frame number : 10350
# Saved frame number : 10360
# Saved frame number : 10370
# Saved frame number : 10380
# Saved frame number : 10390
# Saved frame number : 10400
# Saved frame number : 10410
# Saved frame number : 10420
# Saved frame number : 10430
# Saved frame number : 10440
# Saved frame number : 10450
# Saved frame number : 10460
# Saved frame number : 10470
# Saved frame number : 10480
# Saved frame number : 10490
# Saved frame number : 10500
# Saved frame number : 10510
# Saved frame number : 10520
# Saved frame number : 10530
# Saved frame number : 10540
# Saved frame number : 10550
# Saved frame number : 10560
# Saved frame number : 10570
# Saved frame number : 10580
# Saved frame number : 10590
# Saved frame number : 10600
# Saved frame number : 10610
# Saved frame number : 10620
# Saved frame number : 10630
# Saved frame number : 10640
# Saved frame number : 10650
# Saved frame number : 10660
# Saved frame number : 10670
# Saved frame number : 10680
# Saved frame number : 10690
# Saved frame number : 10700
# Saved frame number : 10710
# Saved frame number : 10720
# Saved frame number : 10730
# Saved frame number : 10740
# Saved frame number : 10750
# Saved frame number : 10760
# Saved frame number : 10770
# Saved frame number : 10780
# Saved frame number : 10790
# Saved frame number : 10800
# Saved frame number : 10810
# Saved frame number : 10820
# Saved frame number : 10830
# Saved frame number : 10840
# Saved frame number : 10850
# Saved frame number : 10860
# Saved frame number : 10870
# Saved frame number : 10880
# Saved frame number : 10890
# Saved frame number : 10900
# Saved frame number : 10910
# Saved frame number : 10920
# Saved frame number : 10930
# Saved frame number : 10940
# Saved frame number : 10950
# Saved frame number : 10960
# Saved frame number : 10970
# Saved frame number : 10980
# Saved frame number : 10990
# Saved frame number : 11000
# Saved frame number : 11010
# Saved frame number : 11020
# Saved frame number : 11030
# Saved frame number : 11040
# Saved frame number : 11050
# Saved frame number : 11060
# Saved frame number : 11070
# Saved frame number : 11080
# Saved frame number : 11090
# Saved frame number : 11100
# Saved frame number : 11110
# Saved frame number : 11120
# Saved frame number : 11130
# Saved frame number : 11140
# Saved frame number : 11150
# Saved frame number : 11160
# Saved frame number : 11170
# Saved frame number : 11180
# Saved frame number : 11190
# Saved frame number : 11200
# Saved frame number : 11210
# Saved frame number : 11220
# Saved frame number : 11230
# Saved frame number : 11240
# Saved frame number : 11250
# Saved frame number : 11260
# Saved frame number : 11270
# Saved frame number : 11280
# Saved frame number : 11290
# Saved frame number : 11300
# Saved frame number : 11310
# Saved frame number : 11320
# Saved frame number : 11330
# Saved frame number : 11340
# Saved frame number : 11350
# Saved frame number : 11360
# Saved frame number : 11370
# Saved frame number : 11380
# Saved frame number : 11390
# Saved frame number : 11400
# Saved frame number : 11410
# Saved frame number : 11420
# Saved frame number : 11430
# Saved frame number : 11440
# Saved frame number : 11450
# Saved frame number : 11460
# Saved frame number : 11470
# Saved frame number : 11480
# Saved frame number : 11490
# Saved frame number : 11500
# Saved frame number : 11510
# Saved frame number : 11520
# Saved frame number : 11530
# Saved frame number : 11540
# Saved frame number : 11550
# Saved frame number : 11560
# Saved frame number : 11570
# Saved frame number : 11580
# Saved frame number : 11590
# Saved frame number : 11600
# Saved frame number : 11610
# Saved frame number : 11620
# Saved frame number : 11630
# Saved frame number : 11640
# Saved frame number : 11650
# Saved frame number : 11660
# Saved frame number : 11670
# Saved frame number : 11680
# Saved frame number : 11690
# Saved frame number : 11700
# Saved frame number : 11710
# Saved frame number : 11720
# Saved frame number : 11730
# Saved frame number : 11740
# Saved frame number : 11750
# Saved frame number : 11760
# Saved frame number : 11770
# Saved frame number : 11780
# Saved frame number : 11790
# Saved frame number : 11800
# Saved frame number : 11810
# Saved frame number : 11820
# Saved frame number : 11830
# Saved frame number : 11840
# Saved frame number : 11850
# Saved frame number : 11860
# Saved frame number : 11870
# Saved frame number : 11880
# Saved frame number : 11890
# Saved frame number : 11900
# Saved frame number : 11910
# Saved frame number : 11920
# Saved frame number : 11930
# Saved frame number : 11940
# Saved frame number : 11950
# Saved frame number : 11960
# Saved frame number : 11970
# Saved frame number : 11980
# Saved frame number : 11990
# Saved frame number : 12000
# Saved frame number : 12010
# Saved frame number : 12020
# Saved frame number : 12030
# Saved frame number : 12040
# Saved frame number : 12050
# Saved frame number : 12060
# Saved frame number : 12070
# Saved frame number : 12080
# Saved frame number : 12090
# Saved frame number : 12100
# Saved frame number : 12110
# Saved frame number : 12120
# Saved frame number : 12130
# Saved frame number : 12140
# Saved frame number : 12150
# Saved frame number : 12160
# Saved frame number : 12170
# Saved frame number : 12180
# Saved frame number : 12190
# Saved frame number : 12200
# Saved frame number : 12210
# Saved frame number : 12220
# Saved frame number : 12230
# Saved frame number : 12240
# Saved frame number : 12250
# Saved frame number : 12260
# Saved frame number : 12270
# Saved frame number : 12280
# Saved frame number : 12290
# Saved frame number : 12300
# Saved frame number : 12310
# Saved frame number : 12320
# Saved frame number : 12330
# Saved frame number : 12340
# Saved frame number : 12350
# Saved frame number : 12360
# Saved frame number : 12370
# Saved frame number : 12380
# Saved frame number : 12390
# Saved frame number : 12400
# Saved frame number : 12410
# Saved frame number : 12420
# Saved frame number : 12430
# Saved frame number : 12440
# Saved frame number : 12450
# Saved frame number : 12460
# Saved frame number : 12470
# Saved frame number : 12480
# Saved frame number : 12490
# Saved frame number : 12500
# Saved frame number : 12510
# Saved frame number : 12520
# Saved frame number : 12530
# Saved frame number : 12540
# Saved frame number : 12550
# Saved frame number : 12560
# Saved frame number : 12570
# Saved frame number : 12580
# Saved frame number : 12590
# Saved frame number : 12600
# Saved frame number : 12610
# Saved frame number : 12620
# Saved frame number : 12630
# Saved frame number : 12640
# Saved frame number : 12650
# Saved frame number : 12660
# Saved frame number : 12670
# Saved frame number : 12680
# Saved frame number : 12690
# Saved frame number : 12700
# Saved frame number : 12710
# Saved frame number : 12720
# Saved frame number : 12730
# Saved frame number : 12740
# Saved frame number : 12750
# Saved frame number : 12760
# Saved frame number : 12770
# Saved frame number : 12780
# Saved frame number : 12790
# Saved frame number : 12800
# Saved frame number : 12810
# Saved frame number : 12820
# Saved frame number : 12830
# Saved frame number : 12840
# Saved frame number : 12850
# Saved frame number : 12860
# Saved frame number : 12870
# Saved frame number : 12880
# Saved frame number : 12890
# Saved frame number : 12900
# Saved frame number : 12910
# Saved frame number : 12920
# Saved frame number : 12930
# Saved frame number : 12940
# Saved frame number : 12950
# Saved frame number : 12960
# Saved frame number : 12970
# Saved frame number : 12980
# Saved frame number : 12990
# Saved frame number : 13000
# Saved frame number : 13010
# Saved frame number : 13020
# Saved frame number : 13030
# Saved frame number : 13040
# Saved frame number : 13050
# Saved frame number : 13060
# Saved frame number : 13070
# Saved frame number : 13080
# Saved frame number : 13090
# Saved frame number : 13100
# Saved frame number : 13110
# Saved frame number : 13120
# Saved frame number : 13130
# Saved frame number : 13140
# Saved frame number : 13150
# Saved frame number : 13160
# Saved frame number : 13170
# Saved frame number : 13180
# Saved frame number : 13190
# Saved frame number : 13200
# Saved frame number : 13210
# Saved frame number : 13220
# Saved frame number : 13230
# Saved frame number : 13240
# Saved frame number : 13250
# Saved frame number : 13260
# Saved frame number : 13270
# Saved frame number : 13280
# Saved frame number : 13290
# Saved frame number : 13300
# Saved frame number : 13310
# Saved frame number : 13320
# Saved frame number : 13330
# Saved frame number : 13340
# Saved frame number : 13350
# Saved frame number : 13360
# Saved frame number : 13370
# Saved frame number : 13380
# Saved frame number : 13390
# Saved frame number : 13400
# Saved frame number : 13410
# Saved frame number : 13420
# Saved frame number : 13430
# Saved frame number : 13440
# Saved frame number : 13450
# Saved frame number : 13460
# Saved frame number : 13470
# Saved frame number : 13480
# Saved frame number : 13490
# Saved frame number : 13500
# Saved frame number : 13510
# Saved frame number : 13520
# Saved frame number : 13530
# Saved frame number : 13540
# Saved frame number : 13550
# Saved frame number : 13560
# Saved frame number : 13570
# Saved frame number : 13580
# Saved frame number : 13590
# Saved frame number : 13600
# Saved frame number : 13610
# Saved frame number : 13620
# Saved frame number : 13630
# Saved frame number : 13640
# Saved frame number : 13650
# Saved frame number : 13660
# Saved frame number : 13670
# Saved frame number : 13680
# Saved frame number : 13690
# Saved frame number : 13700
# Saved frame number : 13710
# Saved frame number : 13720
# Saved frame number : 13730
# Saved frame number : 13740
# Saved frame number : 13750
# Saved frame number : 13760
# Saved frame number : 13770
# Saved frame number : 13780
# Saved frame number : 13790
# Saved frame number : 13800
# Saved frame number : 13810
# Saved frame number : 13820
# Saved frame number : 13830
# Saved frame number : 13840
# Saved frame number : 13850
# Saved frame number : 13860
# Saved frame number : 13870
# Saved frame number : 13880
# Saved frame number : 13890
# Saved frame number : 13900
# Saved frame number : 13910
# Saved frame number : 13920
# Saved frame number : 13930
# Saved frame number : 13940
# Saved frame number : 13950
# Saved frame number : 13960
# Saved frame number : 13970
# Saved frame number : 13980
# Saved frame number : 13990
# Saved frame number : 14000
# Saved frame number : 14010
# Saved frame number : 14020
# Saved frame number : 14030
# Saved frame number : 14040
# Saved frame number : 14050
# Saved frame number : 14060
# Saved frame number : 14070
# Saved frame number : 14080
# Saved frame number : 14090
# Saved frame number : 14100
# Saved frame number : 14110
# Saved frame number : 14120
# Saved frame number : 14130
# Saved frame number : 14140
# Saved frame number : 14150
# Saved frame number : 14160
# Saved frame number : 14170
# Saved frame number : 14180
# Saved frame number : 14190
# Saved frame number : 14200
# Saved frame number : 14210
# Saved frame number : 14220
# Saved frame number : 14230
# Saved frame number : 14240
# Saved frame number : 14250
# Saved frame number : 14260
# Saved frame number : 14270
# Saved frame number : 14280
# Saved frame number : 14290
# Saved frame number : 14300
# Saved frame number : 14310
# Saved frame number : 14320
# Saved frame number : 14330
# Saved frame number : 14340
# Saved frame number : 14350
# Saved frame number : 14360
# Saved frame number : 14370
# Saved frame number : 14380
# Saved frame number : 14390
# Saved frame number : 14400
# Saved frame number : 14410
# Saved frame number : 14420
# Saved frame number : 14430
# Saved frame number : 14440
# Saved frame number : 14450
# Saved frame number : 14460
# Saved frame number : 14470
# Saved frame number : 14480
# Saved frame number : 14490
# Saved frame number : 14500
# Saved frame number : 14510
# Saved frame number : 14520
# Saved frame number : 14530
# Saved frame number : 14540
# Saved frame number : 14550
# Saved frame number : 14560
# Saved frame number : 14570
# Saved frame number : 14580
# Saved frame number : 14590
# Saved frame number : 14600
# Saved frame number : 14610
# Saved frame number : 14620
# Saved frame number : 14630
# Saved frame number : 14640
# Saved frame number : 14650
# Saved frame number : 14660
# Saved frame number : 14670
# Saved frame number : 14680
# Saved frame number : 14690
# Saved frame number : 14700
# Saved frame number : 14710
# Saved frame number : 14720
# Saved frame number : 14730
# Saved frame number : 14740
# Saved frame number : 14750
# Saved frame number : 14760
# Saved frame number : 14770
# Saved frame number : 14780
# Saved frame number : 14790
# Saved frame number : 14800
# Saved frame number : 14810
# Saved frame number : 14820
# Saved frame number : 14830
# Saved frame number : 14840
# Saved frame number : 14850
# Saved frame number : 14860
# Saved frame number : 14870
# Saved frame number : 14880
# Saved frame number : 14890
# Saved frame number : 14900
# Saved frame number : 14910
# Saved frame number : 14920
# Saved frame number : 14930
# Saved frame number : 14940
# Saved frame number : 14950
# Saved frame number : 14960
# Saved frame number : 14970
# Saved frame number : 14980
# Saved frame number : 14990
# Saved frame number : 15000
# Saved frame number : 15010
# Saved frame number : 15020
# Saved frame number : 15030
# Saved frame number : 15040
# Saved frame number : 15050
# Saved frame number : 15060
# Saved frame number : 15070
# Saved frame number : 15080
# Saved frame number : 15090
# Saved frame number : 15100
# Saved frame number : 15110
# Saved frame number : 15120
# Saved frame number : 15130
# Saved frame number : 15140
# Saved frame number : 15150
# Saved frame number : 15160
# Saved frame number : 15170
# Saved frame number : 15180
# Saved frame number : 15190
# Saved frame number : 15200
# Saved frame number : 15210
# Saved frame number : 15220
# Saved frame number : 15230
# Saved frame number : 15240
# Saved frame number : 15250
# Saved frame number : 15260
# Saved frame number : 15270
# Saved frame number : 15280
# Saved frame number : 15290
# Saved frame number : 15300
# Saved frame number : 15310
# Saved frame number : 15320
# Saved frame number : 15330
# Saved frame number : 15340
# Saved frame number : 15350
# Saved frame number : 15360
# Saved frame number : 15370
# Saved frame number : 15380
# Saved frame number : 15390
# Saved frame number : 15400
# Saved frame number : 15410
# Saved frame number : 15420
# Saved frame number : 15430
# Saved frame number : 15440
# Saved frame number : 15450
# Saved frame number : 15460
# Saved frame number : 15470
# Saved frame number : 15480
# Saved frame number : 15490
# Saved frame number : 15500
# Saved frame number : 15510
# Saved frame number : 15520
# Saved frame number : 15530
# Saved frame number : 15540
# Saved frame number : 15550
# Saved frame number : 15560
# Saved frame number : 15570
# Saved frame number : 15580
# Saved frame number : 15590
# Saved frame number : 15600
# Saved frame number : 15610
# Saved frame number : 15620
# Saved frame number : 15630
# Saved frame number : 15640
# Saved frame number : 15650
# Saved frame number : 15660
# Saved frame number : 15670
# Saved frame number : 15680
# Saved frame number : 15690
# Saved frame number : 15700
# Saved frame number : 15710
# Saved frame number : 15720
# Saved frame number : 15730
# Saved frame number : 15740
# Saved frame number : 15750
# Saved frame number : 15760
# Saved frame number : 15770
# Saved frame number : 15780
# Saved frame number : 15790
# Saved frame number : 15800
# Saved frame number : 15810
# Saved frame number : 15820
# Saved frame number : 15830
# Saved frame number : 15840
# Saved frame number : 15850
# Saved frame number : 15860
# Saved frame number : 15870
# Saved frame number : 15880
# Saved frame number : 15890
# Saved frame number : 15900
# Saved frame number : 15910
# Saved frame number : 15920
# Saved frame number : 15930
# Saved frame number : 15940
# Saved frame number : 15950
# Saved frame number : 15960
# Saved frame number : 15970
# Saved frame number : 15980
# Saved frame number : 15990
# Saved frame number : 16000
# Saved frame number : 16010
# Saved frame number : 16020
# Saved frame number : 16030
# Saved frame number : 16040
# Saved frame number : 16050
# Saved frame number : 16060
# Saved frame number : 16070
# Saved frame number : 16080
# Saved frame number : 16090
# Saved frame number : 16100
# Saved frame number : 16110
# Saved frame number : 16120
# Saved frame number : 16130
# Saved frame number : 16140
# Saved frame number : 16150
# Saved frame number : 16160
# Saved frame number : 16170
# Saved frame number : 16180
# Saved frame number : 16190
# Saved frame number : 16200
# Saved frame number : 16210
# Saved frame number : 16220
# Saved frame number : 16230
# Saved frame number : 16240
# Saved frame number : 16250
# Saved frame number : 16260
# Saved frame number : 16270
# Saved frame number : 16280
# Saved frame number : 16290
# Saved frame number : 16300
# Saved frame number : 16310
# Saved frame number : 16320
# Saved frame number : 16330
# Saved frame number : 16340
# Saved frame number : 16350
# Saved frame number : 16360
# Saved frame number : 16370
# Saved frame number : 16380
# Saved frame number : 16390
# Saved frame number : 16400
# Saved frame number : 16410
# Saved frame number : 16420
# Saved frame number : 16430
# Saved frame number : 16440
# Saved frame number : 16450
# Saved frame number : 16460
# Saved frame number : 16470
# Saved frame number : 16480
# Saved frame number : 16490
# Saved frame number : 16500
# Saved frame number : 16510
# Saved frame number : 16520
# Saved frame number : 16530
# Saved frame number : 16540
# Saved frame number : 16550
# Saved frame number : 16560
# Saved frame number : 16570
# Saved frame number : 16580
# Saved frame number : 16590
# Saved frame number : 16600
# Saved frame number : 16610
# Saved frame number : 16620
# Saved frame number : 16630
# Saved frame number : 16640
# Saved frame number : 16650
# Saved frame number : 16660
# Saved frame number : 16670
# Saved frame number : 16680
# Saved frame number : 16690
# Saved frame number : 16700
# Saved frame number : 16710
# Saved frame number : 16720
# Saved frame number : 16730
# Saved frame number : 16740
# Saved frame number : 16750
# Saved frame number : 16760
# Saved frame number : 16770
# Saved frame number : 16780
# Saved frame number : 16790
# Saved frame number : 16800
# Saved frame number : 16810
# Saved frame number : 16820
# Saved frame number : 16830
# Saved frame number : 16840
# Saved frame number : 16850
# Saved frame number : 16860
# Saved frame number : 16870
# Saved frame number : 16880
# Saved frame number : 16890
# Saved frame number : 16900
# Saved frame number : 16910
# Saved frame number : 16920
# Saved frame number : 16930
# Saved frame number : 16940
# Saved frame number : 16950
# Saved frame number : 16960
# Saved frame number : 16970
# Saved frame number : 16980
# Saved frame number : 16990
# Saved frame number : 17000
# Saved frame number : 17010
# Saved frame number : 17020
# Saved frame number : 17030
# Saved frame number : 17040
# Saved frame number : 17050
# Saved frame number : 17060
# Saved frame number : 17070
# Saved frame number : 17080
# Saved frame number : 17090
# Saved frame number : 17100
# Saved frame number : 17110
# Saved frame number : 17120
# Saved frame number : 17130
# Saved frame number : 17140
# Saved frame number : 17150
# Saved frame number : 17160
# Saved frame number : 17170
# Saved frame number : 17180
# Saved frame number : 17190
# Saved frame number : 17200
# Saved frame number : 17210
# Saved frame number : 17220
# Saved frame number : 17230
# Saved frame number : 17240
# Saved frame number : 17250
# Saved frame number : 17260
# Saved frame number : 17270
# Saved frame number : 17280
# Saved frame number : 17290
# Saved frame number : 17300
# Saved frame number : 17310
# Saved frame number : 17320
# Saved frame number : 17330
# Saved frame number : 17340
# Saved frame number : 17350
# Saved frame number : 17360
# Saved frame number : 17370
# Saved frame number : 17380
# Saved frame number : 17390
# Saved frame number : 17400
# Saved frame number : 17410
# Saved frame number : 17420
# Saved frame number : 17430
# Saved frame number : 17440
# Saved frame number : 17450
# Saved frame number : 17460
# Saved frame number : 17470
# Saved frame number : 17480
# Saved frame number : 17490
# Saved frame number : 17500
# Saved frame number : 17510
# Saved frame number : 17520
# Saved frame number : 17530
# Saved frame number : 17540
# Saved frame number : 17550
# Saved frame number : 17560
# Saved frame number : 17570
# Saved frame number : 17580
# Saved frame number : 17590
# Saved frame number : 17600
# Saved frame number : 17610
# Saved frame number : 17620
# Saved frame number : 17630
# Saved frame number : 17640
# Saved frame number : 17650
# Saved frame number : 17660
# Saved frame number : 17670
# Saved frame number : 17680
# Saved frame number : 17690
# Saved frame number : 17700
# Saved frame number : 17710
# Saved frame number : 17720
# Saved frame number : 17730
# Saved frame number : 17740
# Saved frame number : 17750
# Saved frame number : 17760
# Saved frame number : 17770
# Saved frame number : 17780
# Saved frame number : 17790
# Saved frame number : 17800
# Saved frame number : 17810
# Saved frame number : 17820
# Saved frame number : 17830
# Saved frame number : 17840
# Saved frame number : 17850
# Saved frame number : 17860
# Saved frame number : 17870
# Saved frame number : 17880
# Saved frame number : 17890
# Saved frame number : 17900
# Saved frame number : 17910
# Saved frame number : 17920
# Saved frame number : 17930
# Saved frame number : 17940
# Saved frame number : 17950
# Saved frame number : 17960
# Saved frame number : 17970
# Saved frame number : 17980
# Saved frame number : 17990
# Saved frame number : 18000
# Saved frame number : 18010
# Saved frame number : 18020
# Saved frame number : 18030
# Saved frame number : 18040
# Saved frame number : 18050
# Saved frame number : 18060
# Saved frame number : 18070
# Saved frame number : 18080
# Saved frame number : 18090
# Saved frame number : 18100
# Saved frame number : 18110
# Saved frame number : 18120
# Saved frame number : 18130
# Saved frame number : 18140
# Saved frame number : 18150
# Saved frame number : 18160
# Saved frame number : 18170
# Saved frame number : 18180
# Saved frame number : 18190
# Saved frame number : 18200
# Saved frame number : 18210
# Saved frame number : 18220
# Saved frame number : 18230
# Saved frame number : 18240
# Saved frame number : 18250
# Saved frame number : 18260
# Saved frame number : 18270
# Saved frame number : 18280
# Saved frame number : 18290
# Saved frame number : 18300
# Saved frame number : 18310
# Saved frame number : 18320
# Saved frame number : 18330
# Saved frame number : 18340
# Saved frame number : 18350
# Saved frame number : 18360
# Saved frame number : 18370
# Saved frame number : 18380
# Saved frame number : 18390
# Saved frame number : 18400
# Saved frame number : 18410
# Saved frame number : 18420
# Saved frame number : 18430
# Saved frame number : 18440
# Saved frame number : 18450
# Saved frame number : 18460
# Saved frame number : 18470
# Saved frame number : 18480
# Saved frame number : 18490
# Saved frame number : 18500
# Saved frame number : 18510
# Saved frame number : 18520
# Saved frame number : 18530
# Saved frame number : 18540
# Saved frame number : 18550
# Saved frame number : 18560
# Saved frame number : 18570
# Saved frame number : 18580
# Saved frame number : 18590
# Saved frame number : 18600
# Saved frame number : 18610
# Saved frame number : 18620
# Saved frame number : 18630
# Saved frame number : 18640
# Saved frame number : 18650
# Saved frame number : 18660
# Saved frame number : 18670
# Saved frame number : 18680
# Saved frame number : 18690
# Saved frame number : 18700
# Saved frame number : 18710
# Saved frame number : 18720
# Saved frame number : 18730
# Saved frame number : 18740
# Saved frame number : 18750
# Saved frame number : 18760
# Saved frame number : 18770
# Saved frame number : 18780
# Saved frame number : 18790
# Saved frame number : 18800
# Saved frame number : 18810
# Saved frame number : 18820
# Saved frame number : 18830
# Saved frame number : 18840
# Saved frame number : 18850
# Saved frame number : 18860
# Saved frame number : 18870
# Saved frame number : 18880
# Saved frame number : 18890
# Saved frame number : 18900
# Saved frame number : 18910
# Saved frame number : 18920
# Saved frame number : 18930
# Saved frame number : 18940
# Saved frame number : 18950
# Saved frame number : 18960
# Saved frame number : 18970
# Saved frame number : 18980
# Saved frame number : 18990
# Saved frame number : 19000
# Saved frame number : 19010
# Saved frame number : 19020
# Saved frame number : 19030
# Saved frame number : 19040
# Saved frame number : 19050
# Saved frame number : 19060
# Saved frame number : 19070
# Saved frame number : 19080
# Saved frame number : 19090
# Saved frame number : 19100
# Saved frame number : 19110
# Saved frame number : 19120
# Saved frame number : 19130
# Saved frame number : 19140
# Saved frame number : 19150
# Saved frame number : 19160
# Saved frame number : 19170
# Saved frame number : 19180
# Saved frame number : 19190
# Saved frame number : 19200
# Saved frame number : 19210
# Saved frame number : 19220
# Saved frame number : 19230
# Saved frame number : 19240
# Saved frame number : 19250
# Saved frame number : 19260
# Saved frame number : 19270
# Saved frame number : 19280
# Saved frame number : 19290
# Saved frame number : 19300
# Saved frame number : 19310
# Saved frame number : 19320
# Saved frame number : 19330
# Saved frame number : 19340
# Saved frame number : 19350
# Saved frame number : 19360
# Saved frame number : 19370
# Saved frame number : 19380
# Saved frame number : 19390
# Saved frame number : 19400
# Saved frame number : 19410
# Saved frame number : 19420
# Saved frame number : 19430
# Saved frame number : 19440
# Saved frame number : 19450
# Saved frame number : 19460
# Saved frame number : 19470
# Saved frame number : 19480
# Saved frame number : 19490
# Saved frame number : 19500
# Saved frame number : 19510
# Saved frame number : 19520
# Saved frame number : 19530
# Saved frame number : 19540
# Saved frame number : 19550
# Saved frame number : 19560
# Saved frame number : 19570
# Saved frame number : 19580
# Saved frame number : 19590
# Saved frame number : 19600
# Saved frame number : 19610
# Saved frame number : 19620
# Saved frame number : 19630
# Saved frame number : 19640
# Saved frame number : 19650
# Saved frame number : 19660
# Saved frame number : 19670
# Saved frame number : 19680
# Saved frame number : 19690
# Saved frame number : 19700
# Saved frame number : 19710
# Saved frame number : 19720
# Saved frame number : 19730
# Saved frame number : 19740
# Saved frame number : 19750
# Saved frame number : 19760
# Saved frame number : 19770
# Saved frame number : 19780
# Saved frame number : 19790
# Saved frame number : 19800
# Saved frame number : 19810
# Saved frame number : 19820
# Saved frame number : 19830
# Saved frame number : 19840
# Saved frame number : 19850
# Saved frame number : 19860
# Saved frame number : 19870
# Saved frame number : 19880
# Saved frame number : 19890
# Saved frame number : 19900
# Saved frame number : 19910
# Saved frame number : 19920
# Saved frame number : 19930
# Saved frame number : 19940
# Saved frame number : 19950
# Saved frame number : 19960
# Saved frame number : 19970
# Saved frame number : 19980
# Saved frame number : 19990
# Saved frame number : 20000
# Saved frame number : 20010
# Saved frame number : 20020
# Saved frame number : 20030
# Saved frame number : 20040
# Saved frame number : 20050
# Saved frame number : 20060
# Saved frame number : 20070
# Saved frame number : 20080
# Saved frame number : 20090
# Saved frame number : 20100
# Saved frame number : 20110
# Saved frame number : 20120
# Saved frame number : 20130
# Saved frame number : 20140
# Saved frame number : 20150
# Saved frame number : 20160
# Saved frame number : 20170
# Saved frame number : 20180
# Saved frame number : 20190
# Saved frame number : 20200
# Saved frame number : 20210
# Saved frame number : 20220
# Saved frame number : 20230
# Saved frame number : 20240
# Saved frame number : 20250
# Saved frame number : 20260
# Saved frame number : 20270
# Saved frame number : 20280
# Saved frame number : 20290
# Saved frame number : 20300
# Saved frame number : 20310
# Saved frame number : 20320
# Saved frame number : 20330
# Saved frame number : 20340
# Saved frame number : 20350
# Saved frame number : 20360
# Saved frame number : 20370
# Saved frame number : 20380
# Saved frame number : 20390
# Saved frame number : 20400
# Saved frame number : 20410
# Saved frame number : 20420
# Saved frame number : 20430
# Saved frame number : 20440
# Saved frame number : 20450
# Saved frame number : 20460
# Saved frame number : 20470
# Saved frame number : 20480
# Saved frame number : 20490
# Saved frame number : 20500
# Saved frame number : 20510
# Saved frame number : 20520
# Saved frame number : 20530
# Saved frame number : 20540
# Saved frame number : 20550
# Saved frame number : 20560
# Saved frame number : 20570
# Saved frame number : 20580
# Saved frame number : 20590
# Saved frame number : 20600
# Saved frame number : 20610
# Saved frame number : 20620
# Saved frame number : 20630
# Saved frame number : 20640
# Saved frame number : 20650
# Saved frame number : 20660
# Saved frame number : 20670
# Saved frame number : 20680
# Saved frame number : 20690
# Saved frame number : 20700
# Saved frame number : 20710
# Saved frame number : 20720
# Saved frame number : 20730
# Saved frame number : 20740
# Saved frame number : 20750
# Saved frame number : 20760
# Saved frame number : 20770
# Saved frame number : 20780
# Saved frame number : 20790
# Saved frame number : 20800
# Saved frame number : 20810
# Saved frame number : 20820
# Saved frame number : 20830
# Saved frame number : 20840
# Saved frame number : 20850
# Saved frame number : 20860
# Saved frame number : 20870
# Saved frame number : 20880
# Saved frame number : 20890
# Saved frame number : 20900
# Saved frame number : 20910
# Saved frame number : 20920
# Saved frame number : 20930
# Saved frame number : 20940
# Saved frame number : 20950
# Saved frame number : 20960
# Saved frame number : 20970
# Saved frame number : 20980
# Saved frame number : 20990
# Saved frame number : 21000
# Saved frame number : 21010
# Saved frame number : 21020
# Saved frame number : 21030
# Saved frame number : 21040
# Saved frame number : 21050
# Saved frame number : 21060
# Saved frame number : 21070
# Saved frame number : 21080
# Saved frame number : 21090
# Saved frame number : 21100
# Saved frame number : 21110
# Saved frame number : 21120
# Saved frame number : 21130
# Saved frame number : 21140
# Saved frame number : 21150
# Saved frame number : 21160
# Saved frame number : 21170
# Saved frame number : 21180
# Saved frame number : 21190
# Saved frame number : 21200
# Saved frame number : 21210
# Saved frame number : 21220
# Saved frame number : 21230
# Saved frame number : 21240
# Saved frame number : 21250
# Saved frame number : 21260
# Saved frame number : 21270
# Saved frame number : 21280
# Saved frame number : 21290
# Saved frame number : 21300
# Saved frame number : 21310
# Saved frame number : 21320
# Saved frame number : 21330
# Saved frame number : 21340
# Saved frame number : 21350
# Saved frame number : 21360
# Saved frame number : 21370
# Saved frame number : 21380
# Saved frame number : 21390
# Saved frame number : 21400
# Saved frame number : 21410
# Saved frame number : 21420
# Saved frame number : 21430
# Saved frame number : 21440
# Saved frame number : 21450
# Saved frame number : 21460
# Saved frame number : 21470
# Saved frame number : 21480
# Saved frame number : 21490
# Saved frame number : 21500
# Saved frame number : 21510
# Saved frame number : 21520
# Saved frame number : 21530
# Saved frame number : 21540
# Saved frame number : 21550
# Saved frame number : 21560
# Saved frame number : 21570
# Saved frame number : 21580
# Saved frame number : 21590
# Saved frame number : 21600
# Saved frame number : 21610
# Saved frame number : 21620
# Saved frame number : 21630
# Saved frame number : 21640
# Saved frame number : 21650
# Saved frame number : 21660
# Saved frame number : 21670
# Saved frame number : 21680
# Saved frame number : 21690
# Saved frame number : 21700
# Saved frame number : 21710
# Saved frame number : 21720
# Saved frame number : 21730
# Saved frame number : 21740
# Saved frame number : 21750
# Saved frame number : 21760
# Saved frame number : 21770
# Saved frame number : 21780
# Saved frame number : 21790
# Saved frame number : 21800
# Saved frame number : 21810
# Saved frame number : 21820
# Saved frame number : 21830
# Saved frame number : 21840
# Saved frame number : 21850
# Saved frame number : 21860
# Saved frame number : 21870
# Saved frame number : 21880
# Saved frame number : 21890
# Saved frame number : 21900
# Saved frame number : 21910
# Saved frame number : 21920
# Saved frame number : 21930
# Saved frame number : 21940
# Saved frame number : 21950
# Saved frame number : 21960
# Saved frame number : 21970
# Saved frame number : 21980
# Saved frame number : 21990
# Saved frame number : 22000
# Saved frame number : 22010
# Saved frame number : 22020
# Saved frame number : 22030
# Saved frame number : 22040
# Saved frame number : 22050
# Saved frame number : 22060
# Saved frame number : 22070
# Saved frame number : 22080
# Saved frame number : 22090
# Saved frame number : 22100
# Saved frame number : 22110
# Saved frame number : 22120
# Saved frame number : 22130
# Saved frame number : 22140
# Saved frame number : 22150
# Saved frame number : 22160
# Saved frame number : 22170
# Saved frame number : 22180
# Saved frame number : 22190
# Saved frame number : 22200
# Saved frame number : 22210
# Saved frame number : 22220
# Saved frame number : 22230
# Saved frame number : 22240
# Saved frame number : 22250
# Saved frame number : 22260
# Saved frame number : 22270
# Saved frame number : 22280
# Saved frame number : 22290
# Saved frame number : 22300
# Saved frame number : 22310
# Saved frame number : 22320
# Saved frame number : 22330
# Saved frame number : 22340
# Saved frame number : 22350
# Saved frame number : 22360
# Saved frame number : 22370
# Saved frame number : 22380
# Saved frame number : 22390
# Saved frame number : 22400
# Saved frame number : 22410
# Saved frame number : 22420
# Saved frame number : 22430
# Saved frame number : 22440
# Saved frame number : 22450
# Saved frame number : 22460
# Saved frame number : 22470
# Saved frame number : 22480
# Saved frame number : 22490
# Saved frame number : 22500
# Saved frame number : 22510
# Saved frame number : 22520
# Saved frame number : 22530
# Saved frame number : 22540
# Saved frame number : 22550
# Saved frame number : 22560
# Saved frame number : 22570
# Saved frame number : 22580
# Saved frame number : 22590
# Saved frame number : 22600
# Saved frame number : 22610
